# %%
import nltk

# %%
# download punkt model
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/viet/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/viet/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/viet/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
text = "NLTK is a great NLP toolkit. It makes processing text easy!"

# %%
text = text.lower()

# %%
senctences = sent_tokenize(text)

# %%
senctences
# Out:
# ['nltk is a great nlp toolkit.', 'it makes processing text easy!']

# %%
words = word_tokenize(text)
words
# Out:
# ['nltk',
#  'is',
#  'a',
#  'great',
#  'nlp',
#  'toolkit',
#  '.',
#  'it',
#  'makes',
#  'processing',
#  'text',
#  'easy',
#  '!']

# %%
stop_words = set(stopwords.words('english'))

# %%
filterd_words = [word for word in words if word not in stop_words]
filterd_words
# Out:
# ['nltk',
#  'great',
#  'nlp',
#  'toolkit',
#  '.',
#  'makes',
#  'processing',
#  'text',
#  'easy',
#  '!']
