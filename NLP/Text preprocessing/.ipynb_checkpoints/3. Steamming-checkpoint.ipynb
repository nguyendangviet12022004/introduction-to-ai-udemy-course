# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
words =  ["study", "studies", "studying", "studied", "student", "students"]

# %%
for w in words:
    print(w + ": " + ps.stem(w))
# Out:
# study: studi
# studies: studi
# studying: studi
# studied: studi
# student: student
# students: student
